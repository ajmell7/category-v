# %%
#!/usr/bin/env python3
"""
Notebook to store plotting functions and related data processing functions.
"""
from concurrent.futures import ThreadPoolExecutor, as_completed
import contextily as cx
from datetime import datetime
import math
from matplotlib import patches
import matplotlib.pyplot as plt
import matplotlib.transforms as mtransforms
import numpy as np
import os
import pandas as pd

from helpers.hurricane_helpers import (
    get_hurricane_bin_midpoint_times,
    get_hurricane_bin_start_times,
    get_hurricane_bin_end_times,
    list_all_hurricanes,
    interpolate_besttrack_for_code,
    interpolate_all_hurricanes_besttrack
)
from helpers.ships_helpers import save_ships_data, interpolate_ships_info_for_hurricane, interpolate_all_hurricanes_ships
from helpers.glm_helpers import process_all_hurricanes_glm, process_glm_info_for_hurricane

from helpers.orchestration_helpers import download_all_data_for_hurricane, download_all_data_for_all_hurricanes

from constants import TS_MIN, TS_MAX, DEFAULT_REGION, MAX_RMW_MULT, METERS_PER_KT, BIN_TIME_INTERVAL_MINUTES, MINUTES_PER_DAY

# %%
#If we haven't generated the list of hurricanes, do that first
print(list_all_hurricanes())

# %%
#If we haven't generated the GLM data, do that
#We need that data first before we can make plots
download_all_data_for_all_hurricanes(region="atl")

# %%
#Updated T score method
def calculate_t_scores_and_intens_status(besttrack_df):
    '''
    Calculate hurricane T scores by time bin from best track data

    Args:
        besttrack_df: Input best track data to use for T score calculations

    Returns:
        besttrack_df: Best track dataset with a new column added for T values
    '''
    #Define the thresholds and corresponding T scores
    t_thresholds = [27.5, 32.5, 40, 50, 60, 71, 83.5, 96, 108.5, 121, 133.5, 147.5, 162.5, 177.5]
    t_values = [1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5]

    #Calculate T scores for each best track row
    winds = besttrack_df['Maximum Sustained Winds'].to_numpy()
    t_indices = np.digitize(winds, t_thresholds, right=True)

    besttrack_df['T Score'] = np.array(t_values)[t_indices]

    #Calculate intensification status
    bins_per_24_hrs = int(MINUTES_PER_DAY / BIN_TIME_INTERVAL_MINUTES)
    #print(bins_per_24_hrs)

    #Define the thresholds and corresponding intensification categories
    intens_thresholds = [-30, -10, 10, 30]
    intens_values = ['RW', 'W', 'NC', 'I', 'RI']

    #change in wind speed over next 24 hrs
    winds_diffs = winds[bins_per_24_hrs:] - winds[:-bins_per_24_hrs]

    #Calculate intensification categories
    intens_indices = np.digitize(winds_diffs, intens_thresholds)

    intens_cats = np.array(intens_values)[intens_indices]

    #Add "no data" values for last 24 hours
    intens_cats = np.pad(intens_cats, (0, bins_per_24_hrs), 'constant', constant_values=('ND'))

    besttrack_df['Intensification Status'] = intens_cats
    
    return besttrack_df

# %%
def get_filtered_glm_data_for_hurricane(row, t_score = 'all', intens_status='all'):
    '''
    Get GLM lightning data for a specific hurricane. Only returns the data 
    within those time bins that match the t score and intensification status 
    given.

    Args:
        row: Row in hurricane list corresponding to the storm you want (with the
            hurricane list being the output of list_all_hurricanes())
        t_score: The T score to use for filtering GLM data. Possible values are
            1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, and 'all' (where 
            'all' means the function returns data for all T scores)
        intens_status: The intensification status to use for filtering GLM data.
            Possible values are:
                'RW' (rapid weakening only - wind speed decreases by >30kt in
                    next 24hrs),
                'W' (weakening only - wind speed decreases by 10-30kt in next
                    24hrs), 
                'NC' (no change only - wind speed changes by <10kt in next 
                    24hrs), 
                'I' (intensifying only - wind speed increases by 10-30kt in next 
                    24hrs), 
                'RI' (rapidly intensifying only - wind speed increases by >30kt
                    in next 24hrs),
                'all' (do not filter by intensification status - return data for
                    all statuses)

    Returns:
        curr_glm_joined: Joined dataframe of GLM, best track, and SHIPS data for
            time bins meeting T score and intensification criteria within the 
            specified hurricane
    '''
    #print('filtered_glm_data', datetime.now())
    #hurricane info
    curr_code = row['code']
    curr_name = row['name']
    curr_year = row['year']

    #Read best track, ships, glm data
    curr_path_base = f'data/storms/{curr_name}_{curr_year}'
    curr_besttrack_csv_path = f'{curr_path_base}/hurricane/besttrack.csv'
    curr_besttrack_df = pd.read_csv(curr_besttrack_csv_path)
    #print(datetime.now())
    curr_besttrack_df = calculate_t_scores_and_intens_status(curr_besttrack_df)
    #print(datetime.now())

    #Define masks
    #land mask
    land_mask = (curr_besttrack_df['Land'] == 'N')

    #radius of maximum winds mask (must have data)
    rmw_mask = (curr_besttrack_df['Radius of Maximum Winds'] != -999)

    #t score mask
    if t_score == 'all':
        t_score_mask = land_mask
    else:
        t_score_mask = (curr_besttrack_df['T Score'] == t_score)

    #intensification mask
    if intens_status == 'all':
        intens_status_mask = land_mask
    else:
        intens_status_mask = ((curr_besttrack_df['Intensification Status'] == intens_status))

    #Filter best track data by mask
    curr_besttrack_filtered = curr_besttrack_df[land_mask & t_score_mask & intens_status_mask & rmw_mask]

    #print(datetime.now())

    if curr_besttrack_filtered.empty:
        return None
    
    #print(datetime.now())

    curr_ships_csv_path = f'{curr_path_base}/ships/ships_interpolated.csv'
    curr_ships_df = pd.read_csv(curr_ships_csv_path)

    #print(datetime.now())

    curr_glm_csv_path = f'{curr_path_base}/glm/groups.csv'
    cols_needed = ['Hurricane Code', 'Bin Time', 'Distance From Hurricane Center (m)', 'Direction from Hurricane Center (deg)']
    curr_glm_df = pd.read_csv(curr_glm_csv_path, usecols=cols_needed)

    #print(datetime.now())
    
    #join with best track data and filter by t score
    curr_besttrack_filtered.set_index("Timestamp", inplace=True)
    curr_ships_df.set_index("Timestamp", inplace=True)

    #print(datetime.now())

    curr_glm_besttrack = curr_glm_df.join(curr_besttrack_filtered, on="Bin Time", how="inner")
    #curr_glm_besttrack = curr_glm_df.join(curr_besttrack_filtered, left_on="Bin Time", right_on="Timestamp", how="inner")
    #print(datetime.now())
    curr_glm_joined = curr_glm_besttrack.join(curr_ships_df, on="Bin Time", how="inner")
    #curr_glm_joined = curr_glm_besttrack.join(curr_ships_df, left_on="Bin Time", right_on = "Timestamp", how="inner")

    #filter curr_glm_joined to exclude nan shear directions
    if curr_glm_joined is not None:
        curr_glm_joined = curr_glm_joined[curr_glm_joined['Shear Direction (deg)'].notnull()]
    
    #print(datetime.now())
    return curr_glm_joined

#hurr_name
def get_filtered_glm_data(region=DEFAULT_REGION, hurr_name = 'all', t_score = 'all', intens_status='all'):
    '''
    Get combined GLM lightning data for a specific hurricane, or for all 
    hurricanes in a region. Only returns the data within those time bins that 
    match the t score, intensification status, and hurricane name filter given

    Args:
        region: Region whose hurricane data we want to compile
        hurr_name: Name of hurricane whose data we want to use. If we want all
            hurricanes in a region, input 'all' here. Case-insensitive.
        t_score: The T score to use for filtering GLM data. Possible values are
            1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, and 'all' (where 
            'all' means the function returns data for all T scores)
        intens_status: The intensification status to use for filtering GLM data.
            Possible values are:
                'RW' (rapid weakening only - wind speed decreases by >30kt in
                    next 24hrs),
                'W' (weakening only - wind speed decreases by 10-30kt in next
                    24hrs), 
                'NC' (no change only - wind speed changes by <10kt in next 
                    24hrs), 
                'I' (intensifying only - wind speed increases by 10-30kt in
                    next 24hrs), 
                'RI' (rapidly intensifying only - wind speed increases by >30kt
                    in next 24hrs),
                'all' (do not filter by intensification status - return data for
                    all statuses)

    Returns:
        glm_data_filtered: Joined dataframe of GLM, best track, and SHIPS data 
            for time bins meeting T score, intensification, and hurricane name
            criteria
    '''
    #compiled df of glm data across hurricanes (initialize as null)
    glm_data_filtered = None

    #read hurricanes from hurricane list file
    list_csv_path = f'data/global/hurricane/{region}_hurricane_list_{TS_MIN.strftime("%Y%m%d")}_{TS_MAX.strftime("%Y%m%d")}.csv'
    if not os.path.exists(list_csv_path):
        raise FileNotFoundError(f"Hurricane list CSV not found at {list_csv_path}. Run list_all_hurricanes(region='{region}') first.")
    
    hurricanes_df = pd.read_csv(list_csv_path, parse_dates=['start_date', 'end_date'])
    if hurr_name != 'all':
        hurricanes_df = hurricanes_df[hurricanes_df['name'] == hurr_name.upper()]

    total = len(hurricanes_df)
  
    print(f"\n{'='*80}")
    print(f"Processing all data for {total} hurricanes from {region} region")
    print(f"{'='*80}\n")
    
    #loop through hurricanes and grab data points with desired t score
    i = 1
    for idx, row in hurricanes_df.iterrows():
        #print(row)
        curr_name = row['name']
        print(f"Processing data for hurricane {curr_name}: {i}/{total}")

        #Get filtered glm data for hurricane
        curr_glm_joined = get_filtered_glm_data_for_hurricane(row, t_score, intens_status)

        #Add filtered data to compiled df
        if glm_data_filtered is None:
            glm_data_filtered = curr_glm_joined
        else:
            glm_data_filtered = pd.concat([glm_data_filtered, curr_glm_joined])
        
        i += 1
    
    #filter glm_data_filtered to exclude nan shear directions
    if glm_data_filtered is not None:
        glm_data_filtered = glm_data_filtered[glm_data_filtered['Shear Direction (deg)'].notnull()]
    
    return glm_data_filtered

# %%
def calculate_bin_density_radial(glm_bin_data_filtered, n_bins_radial, n_bins_angular, bin_size_radial_rmw_mult, min_rmw=0):
    '''
    Plot lightning density by bin, where each bin is a range of r and theta 
    values in polar coords. Meant to be used on an individual storm and time 
    bin.

    Args:
        glm_bin_data_filtered: Dataframe containing joined GLM, best track,
            and SHIPS data for the given time bin
        n_bins_radial: The number of bins in the radial direction
        n_bins_angular: The number of bins in the angular direction
        bin_size_radial_rmw_mult: The bin size in the radial direction as a 
            multiple of the hurricane's RMW
        min_rmw: The minimum distance from the hurricane center that the
            radial bins cover (this is here so we can calculate density
            specifically in the rain bands, in which case we would input
            the value 1.5)

    Returns:
        dens_by_bin: A numpy array storing the lightning density for each
            bin. Density is in groups per km^2.
    '''
    #Extract RMW
    curr_rmw = glm_bin_data_filtered["Radius of Maximum Winds"].iloc[0]

    #Radial and angular coordinates to np array (for speed optimixation)
    distances = glm_bin_data_filtered["Distance_RMW_Mult"].to_numpy()
    #print(distances)
    angles = glm_bin_data_filtered["Direction From Hurricane Center Relative To Wind Shear (deg)"].to_numpy()
    #print(glm_bin_data_filtered)
    #print(angles)

    #Define bins
    radial_edges = min_rmw + bin_size_radial_rmw_mult * np.arange(n_bins_radial + 1)
    angular_edges = np.linspace(0, 360, n_bins_angular + 1)

    #Count points per bin using digitize
    radial_idx = np.digitize(distances, radial_edges) - 1
    angular_idx = np.digitize(angles, angular_edges) - 1

    #print(radial_idx)
    #print(angular_idx)

    #Clip digitize array to avoid errors
    #radial_idx = np.clip(radial_idx, 0, n_bins_radial - 1)
    #angular_idx = np.clip(angular_idx, 0, n_bins_angular - 1)

    #Count points in each bin
    dens_by_bin = np.zeros((n_bins_radial, n_bins_angular))
    for r in range(n_bins_radial):
        for a in range(n_bins_angular):
            mask = (radial_idx == r) & (angular_idx == a)
            curr_ngroups = np.sum(mask)
            #Divide by area
            min_dist = radial_edges[r]
            max_dist = radial_edges[r + 1]
            bin_area = (1/n_bins_angular) * np.pi*((max_dist*curr_rmw*METERS_PER_KT/1000)**2 - (min_dist*curr_rmw*METERS_PER_KT/1000)**2)
            dens_by_bin[r, a] = curr_ngroups / bin_area
    #print(dens_by_bin)
    return dens_by_bin


def calculate_bin_density_rmw_xy(glm_bin_data_filtered, bin_size_x=0.1, bin_size_y = 0.1, max_rmw_mult=MAX_RMW_MULT):
    '''
    Plot lightning density by bin, where each bin is a range of RMW_x and RMW_y.
    in shear coords. Meant to be used on an individual storm and time bin.

    Args:
        glm_bin_data_filtered: Dataframe containing joined GLM, best track, and 
            SHIPS data for the given time bin
        bin_size_x: The bin size along the shear coordinate x axis (as a 
            multiple of the storm's RMW)
        bin_size_y: The bin size along the shear coordinate y axis (as a 
            multiple of the storm's RMW)
        max_rmw_mult: The maximum distance away from the center to get data (as 
            a multiple of the storm's RMW)

    Returns:
        dens_by_bin: A numpy array storing the lightning density for each bin. 
            Density is in groups per km^2.
    '''
    #Extract radius of maximum winds
    curr_rmw = glm_bin_data_filtered["Radius of Maximum Winds"].iloc[0]

    #RMW Coordinates to np array (for speed optimization)
    x = glm_bin_data_filtered["RMW X in Shear Coordinates"].to_numpy()
    y = glm_bin_data_filtered["RMW Y in Shear Coordinates"].to_numpy()

    #Define bins
    n_bins_x = int(max_rmw_mult * 2 / bin_size_x)
    n_bins_y = int(max_rmw_mult * 2 / bin_size_y)
    x_edges = np.linspace(-n_bins_x/2*bin_size_x, n_bins_x/2*bin_size_x, n_bins_x + 1)
    y_edges = np.linspace(-n_bins_y/2*bin_size_y, n_bins_y/2*bin_size_y, n_bins_y + 1)

    #Initialize numpy array for densities (for efficiency)
    #group_counts = np.zeros((n_bins_radial, n_bins_angular))
    dens_by_bin = np.zeros((n_bins_x, n_bins_y))

    # Histogram counts
    counts, _, _ = np.histogram2d(x, y, bins=[x_edges, y_edges])

    # Convert to density
    bin_area = bin_size_x * bin_size_y * curr_rmw**2
    dens_by_bin = counts / bin_area

    #print(dens_by_bin)

    # Mask bins with a portion outside max_rmw_mult circle
    #Create 2D arrays for bin corners
    xv_min, yv_min = np.meshgrid(x_edges[:-1], y_edges[:-1], indexing='ij')
    xv_max, yv_max = np.meshgrid(x_edges[1:], y_edges[1:], indexing='ij')

    #Compute distance to furthest bin corner
    furthest_corner = np.maximum.reduce([
        np.sqrt(xv_min**2 + yv_min**2),
        np.sqrt(xv_min**2 + yv_max**2),
        np.sqrt(xv_max**2 + yv_min**2),
        np.sqrt(xv_max**2 + yv_max**2)
    ])

    #Mask if that furthest distance is beyond max_rmw_mult
    mask = furthest_corner > max_rmw_mult
    dens_by_bin[mask] = 0
    return dens_by_bin

# %%
#Normalize - simple but clear to make a method
#Divide all of the bin density values by the maximum values
def dens_normalize(bin_values):
    '''
    Normalize an array of lightning density values. This means that all 
    densities are scaled so that the highest density value is 1. We do this 
    for each time bin, and then again after combining the dataa for all time 
    bins.

    Args:
        bin_values: The input array of bin density values

    Returns:
        The output array of normalized bin density values
    '''
    if bin_values.max() == 0:
        return bin_values
    else:
        return bin_values / bin_values.max()

# %%
#plotting methods
def plot_bin_lightning(final_df, bin_start, bin_end, center_lat, center_lon, box_size):
    '''
    Plot lightning groups in vicinity of hurricane center

    Args:
        final_df: Dataframe containing lightning group data within time bin
        bin_start: Start datetime of bin
        bin_end: End datetime of bin
        center_lat: Latitude of hurricane center to draw on plot
        center_lon: Longitude of hurricane center to draw on plot
        box_size: Size of box around hurricane center to show in plot

    Returns:
        None (just shows plot)
    '''
    fig, ax = plt.subplots(figsize=(8,8))
    plt.scatter(final_df['Group Longitude'], final_df['Group Latitude'], s=2, label='Lightning Group')
    plt.scatter(center_lon, center_lat, color='black', label='Hurricane Center')
    plt.xlim(center_lon - box_size, center_lon + box_size)
    plt.ylim(center_lat - box_size, center_lat + box_size)
    plt.xlabel('Longitude (deg)')
    plt.ylabel('Latitude (deg)')
    cx.add_basemap(ax, crs="EPSG:4326", source=cx.providers.OpenStreetMap.Mapnik)
    plt.title(f'Lightning Groups Near Hurricane Ian Center, {bin_start}-{bin_end}')
    plt.legend()
    plt.show()


def plot_shear_dist_azimuth(dens_by_bin, hurr_subset_str, bin_size_radial_rmw_mult=5, n_bins_radial = 1, n_bins_angular = 12):
    '''
    Plot lightning frequency by direction from center (in shear coordinates)

    Args:
        dens_by_bin: Dataframe containing normalized lightning frequency by bin
            (each bin is a range of r and theta values in polar coords) 
        hurr_subset_str: String specifying what subset of the hurricane data is
            being used (generally will be defined in get_filtered_glm_data)
        bin_size_radial_rmw_mult: The bin size in the radial direction as a 
            multiple of the hurricane's RMW
        n_bins_radial: The number of bins in the radial direction
        n_bins_angular: The number of bins in the angular direction

    Returns:
        None - shows plot and saves to plots subfolder on disk as PNG
    '''
    #create density by bin array
    # define binning
    rbins = np.linspace(0, n_bins_radial * bin_size_radial_rmw_mult, n_bins_radial + 1)
    abins = np.linspace(0,2*np.pi, n_bins_angular + 1)

    #print(rbins)
    #print(abins)

    #split each angular bin in 10 to avoid problems with straight lines
    abins_fine = np.linspace(
        0,
        2*np.pi,
        n_bins_angular * 100 + 1
    )

    #upsample density array for larger list of angular bins
    dens_fine = np.repeat(dens_by_bin, 100, axis=1)

    #set up colormap
    cmap = plt.get_cmap("magma_r").copy()
    cmap.set_under("white")

    # plot
    fig, ax = plt.subplots(subplot_kw=dict(projection="polar"))

    #show angles using geographic convention, not mathematical
    ax.set_theta_zero_location("N")
    ax.set_theta_direction(-1)  

    #no RMW rings
    ax.yaxis.grid(False)
    ax.set_yticklabels([])

    #print(dens_by_bin.T.shape)
    pc = ax.pcolormesh(abins_fine, rbins, dens_fine, vmin=0.0001, vmax=1, cmap="magma_r")
    cb = fig.colorbar(pc)
    cb.set_label('Normalized Lightning Frequency', labelpad=20, y=0.5, rotation=270)

    #wind shear arrow
    ax.annotate(
        "Vertical \nWind \nShear",
        xy=(-0.08, 0.9),       
        xytext=(-0.08, 0.6),    
        xycoords=ax.transAxes,
        textcoords=ax.transAxes,
        ha="center",
        arrowprops=dict(arrowstyle="->", lw=2),
        annotation_clip=False
    )

    fig.suptitle(f'Lightning by Direction from Storm Center Relative to Wind Shear, \n{hurr_subset_str}', y=1.08)
    #fig.suptitle(f'Lightning by Distance and Direction from Storm Center, Hurricane Ian {bin_start}-{bin_end}')

    #Make sure that title isn't cut off
    #plt.tight_layout()
    #plt.subplots_adjust(top=0.92)
    
    plt.savefig(f'plots/azimuth/{hurr_subset_str.split('(')[0].replace(',', '').replace('=', '').replace('.', '_').replace(' ', '_')}_azimuth.png', bbox_inches='tight')
    #plt.show()


def plot_shear_dist_rmw_xy(dens_by_bin, hurr_subset_str, max_rmw_mult=MAX_RMW_MULT, bin_size_x=0.1, bin_size_y=0.1):
    '''
    Plot lightning frequency by position in shear coordinates (scaled by RMW)

    Args:
        dens_by_bin: Dataframe containing normalized lightning frequency by bin
            (each bin is a range of RMW_x and RMW_y in shear coords) 
        hurr_subset_str: String specifying what subset of the hurricane data is
            being used (generally will be defined in get_filtered_glm_data)
        max_rmw_mult: The maximum distance away from the center to plot data (as 
            a multiple of the storm's RMW)
        bin_size_x: The bin size in the x direction (as a multiple of RMW in
            shear coords)
        bin_size_y: The bin size in the y direction (as a multiple of RMW in
            shear coords)

    Returns:
        None - shows plot and saves to plots subfolder on disk as PNG
    '''
    n_bins_x, n_bins_y = dens_by_bin.shape

    #define binning
    xbins = np.linspace(-1 * bin_size_x * (n_bins_x / 2), bin_size_x * (n_bins_x / 2), n_bins_x + 1)
    ybins = np.linspace(-1 * bin_size_y * (n_bins_y / 2), bin_size_y * (n_bins_y / 2), n_bins_y + 1)

    #print(rbins)
    #print(abins)

    #Set up color map (we want 0 lightning values to appear as white)
    cmap = plt.get_cmap("magma_r").copy()
    cmap.set_under("white")

    #plot
    fig, ax = plt.subplots(subplot_kw=dict())

    #shade bins
    pc = ax.pcolormesh(xbins, ybins, np.transpose(dens_by_bin), vmin=0.0001, vmax=1, cmap=cmap)
    cb = fig.colorbar(pc)
    cb.set_label('Normalized Lightning Frequency', labelpad=20, y=0.5, rotation=270)

    #Add axes and circles 
    ax.spines['left'].set_position('zero')
    ax.spines['bottom'].set_position('zero')

    for rad in range(5):
        ax.add_patch(plt.Circle((0, 0), rad+1, color='black', fill=False))

    #keep RMW coord labels from colliding with circles
    #Remove the tick labels
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    #Manually add in text (blah)
    for lab in [-4, -2, 2, 4]:
        plt.text((lab * 0.1 + 0.52), 0.52, str(abs(lab)),
            horizontalalignment='center',
            verticalalignment='center',
            transform = ax.transAxes)
        #y label
        plt.text(0.52, (lab * 0.1 + 0.52), str(abs(lab)),
            horizontalalignment='center',
            verticalalignment='center',
            transform = ax.transAxes)
    

    #wind shear arrow
    ax.annotate(
        "Vertical \nWind \nShear",
        xy=(-0.08, 0.9),       
        xytext=(-0.08, 0.6),    
        xycoords=ax.transAxes,
        textcoords=ax.transAxes,
        ha="center",
        arrowprops=dict(arrowstyle="->", lw=2),
        annotation_clip=False
    )

    #title and axis labels
    fig.suptitle(f'Lightning by Shear Coordinates Relative to RMW, \n{hurr_subset_str}', y=1.08)

    plt.text(-0.1, 0.5, 'Distance/\nRMW',
        horizontalalignment='center',
        verticalalignment='center',
        transform = ax.transAxes)
    plt.text(0.5, 1.05, 'Distance/RMW',
        horizontalalignment='center',
        verticalalignment='center',
        transform = ax.transAxes)
    plt.savefig(f'plots/rmwxy/{hurr_subset_str.split('(')[0].replace(',', '').replace('=', '').replace('.', '_').replace(' ', '_')}_RMWXY.png', bbox_inches='tight')
    #plt.show()

# %%
#Putting everything together - gets filtered data, processes/normalizes and plots it
def plot_filtered_data(region=DEFAULT_REGION, hurr_name = 'all', t_score = 'all', intens_status='all'):
    '''
    Plot normalized lightning frequency by direction from hurricane center in 
    shear coordinates (bins are pie slices around the center), and normalized 
    frequency by shear x and y coordinates (bins are squares around hurricane
    center) Data used will be combined GLM lightning data for a specific 
    hurricane, or for all hurricanes in a region, for time bins that match the 
    t score, intensification status, and hurricane name filter given.


    Args:
        region: Region whose hurricane data we want to compile
        hurr_name: Name of hurricane whose data we want to use. If we want all
            hurricanes in a region, input 'all' here. Case-insensitive.
        t_score: The T score to use for filtering GLM data. Possible values are
            1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, and 'all' (where 
            'all' means the function returns data for all T scores)
        intens_status: The intensification status to use for filtering GLM data.
            Possible values are:
                'RW' (rapid weakening only - wind speed decreases by >30kt in
                    next 24hrs),
                'W' (weakening only - wind speed decreases by 10-30kt in next
                    24hrs), 
                'NC' (no change only - wind speed changes by <10kt in next 
                    24hrs), 
                'I' (intensifying only - wind speed increases by 10-30kt in
                    next 24hrs), 
                'RI' (rapidly intensifying only - wind speed increases by >30kt
                    in next 24hrs),
                'all' (do not filter by intensification status - return data for
                    all statuses)

    Returns:
        None - just shows plots and saves to disk per the individual plotting
            methods plot_shear_dist_rmw_xy and plot_shear_dist_azimuth
    '''
    #parameters for angular-only lightning bins
    #all
    n_bins_radial = 1
    n_bins_angular = 12
    bin_size_radial_rmw_mult = 5
    min_rmw = 0

    #rainbands
    #bin_size_radial_rmw_mult = 3.5
    #min_rmw = 1.5

    #inner core
    #bin_size_radial_rmw_mult = 1.5
    #min_rmw=0

    #parameters for rmw_x/rmw_y lightning bins
    #get time bins
    total_time_bins = 0

    #Initialize array for summing bin density values
    dens_norm_sum_az = None
    dens_norm_sum_rmw_xy = None

    #Read hurricanes from hurricane list file
    list_csv_path = f'data/global/hurricane/{region}_hurricane_list_{TS_MIN.strftime("%Y%m%d")}_{TS_MAX.strftime("%Y%m%d")}.csv'
    if not os.path.exists(list_csv_path):
        raise FileNotFoundError(f"Hurricane list CSV not found at {list_csv_path}. Run list_all_hurricanes(region='{region}') first.")
    
    hurricanes_df = pd.read_csv(list_csv_path, parse_dates=['start_date', 'end_date'])
    if hurr_name != 'all':
        hurricanes_df = hurricanes_df[hurricanes_df['name'] == hurr_name.upper()]

    total = len(hurricanes_df)
  
    print(f"\n{'='*80}")
    print(f"Processing all data for {total} hurricanes from {region} region")
    print(f"{'='*80}\n")

    #Loop through hurricanes and get normalized densities per hurricane (avoids
    #overwhelming RAM with a giant merged dataset)
    i_hurr = 0
    for idx, row in hurricanes_df.iterrows():
        i_hurr += 1
        #print(row)
        curr_name = row['name']
        print(f"Processing data for hurricane {curr_name}: {i_hurr}/{total}")
        #print(datetime.now())
        glm_data_filtered = get_filtered_glm_data_for_hurricane(row, t_score=t_score, intens_status=intens_status)
        #print(datetime.now())

        if (glm_data_filtered is None or glm_data_filtered.empty):
            #print('No data meeting filter criteria')
            continue

        #Process RMW multiple. Filter by within 5 RMWs
        glm_data_filtered["Distance From Hurricane Center (kt)"] = glm_data_filtered["Distance From Hurricane Center (m)"] / METERS_PER_KT
        glm_data_filtered["Distance_RMW_Mult"] = glm_data_filtered["Distance From Hurricane Center (kt)"] / glm_data_filtered["Radius of Maximum Winds"]
        glm_data_filtered = glm_data_filtered[glm_data_filtered['Distance_RMW_Mult'] < MAX_RMW_MULT]

        #print(datetime.now())

        #Process shear coordinate direction
        glm_data_filtered["Direction From Hurricane Center Relative To Wind Shear (deg)"] = ((glm_data_filtered["Direction from Hurricane Center (deg)"] - glm_data_filtered["Shear Direction (deg)"]) % 360)

        #Calculate shear RMW x and y coordinates
        glm_data_filtered["RMW X in Shear Coordinates"] = glm_data_filtered["Distance_RMW_Mult"]*np.sin(np.radians(glm_data_filtered["Direction From Hurricane Center Relative To Wind Shear (deg)"]))
        glm_data_filtered["RMW Y in Shear Coordinates"] = glm_data_filtered["Distance_RMW_Mult"]*np.cos(np.radians(glm_data_filtered["Direction From Hurricane Center Relative To Wind Shear (deg)"]))

        #print(glm_data_filtered[glm_data_filtered["Distance_RMW_Mult"] < 5])
        #print(datetime.now())

        #group glm data by time bins and hurricane codes
        glm_data_grouped = glm_data_filtered.groupby(["Hurricane Code", "Bin Time"])

        #Number of time bins for hurricane - with I could just reuse glm_data_grouped
        #but cannot
        curr_time_bins = len(glm_data_filtered[["Hurricane Code", "Bin Time"]].drop_duplicates().to_numpy())
        total_time_bins += curr_time_bins

        #index number (for output messages)
        i_timestamp = 0

        #print(datetime.now())
        #Loop through time bins in grouped GLM data
        for (curr_hurr_code, curr_timestamp), curr_glm_data in glm_data_grouped:
            i_timestamp += 1
            #print(f'Extracting and normalizing data for bin {i_timestamp}/{curr_time_bins}: Hurricane {curr_hurr_code}, {curr_timestamp}')

            #Calculate bin densities and normalize
            curr_bin_dens_az = calculate_bin_density_radial(curr_glm_data, n_bins_radial, n_bins_angular, bin_size_radial_rmw_mult)
            #print(curr_bin_dens_az)
            curr_bin_dens_rmw_xy = calculate_bin_density_rmw_xy(curr_glm_data)
            #curr_bin_dens_rmw_xy = calculate_bin_density_rmw_xy(curr_glm_data, bin_size_y=0.2)#
            dens_norm_az = dens_normalize(curr_bin_dens_az)
            #print(dens_norm_az)
            dens_norm_rmw_xy = dens_normalize(curr_bin_dens_rmw_xy)
            #print(dens_norm_rmw_xy[45:55, 45:55])

            #Add to summed bin density array
            if dens_norm_sum_az is None:
                dens_norm_sum_az = dens_norm_az
            else:
                dens_norm_sum_az += dens_norm_az
            #print(dens_norm_sum_az)

            if dens_norm_sum_rmw_xy is None:
                dens_norm_sum_rmw_xy = dens_norm_rmw_xy
            else:
                dens_norm_sum_rmw_xy += dens_norm_rmw_xy
            #print(dens_norm_sum_rmw_xy[45:55, 45:55])
        #print(datetime.now())
    #
    if dens_norm_sum_az is None:
        print("No data meeting filter criteria")
        return None
    
    #Normalize again
    dens_all_twicenormed_az = dens_normalize(dens_norm_sum_az)
    dens_all_twicenormed_rmw_xy = dens_normalize(dens_norm_sum_rmw_xy)


    #plot_shear_dist(dens_all_twicenormed, hurr_subset_str, bin_size_radial_rmw_mult, n_bins_radial, n_bins_angular)
    #dens_all_twicenormed

    #print(dens_all_twicenormed_rmw_xy.shape)
    #Create plot title
    region_str = f'{region} Basin'
    if region == 'atl':
        region_str = 'Atlantic Basin'
    if region == 'pac':
        region_str = 'Eastern Pacific Basin'

    hurr_str = f'Hurricane {hurr_name.title()}'
    if hurr_name == 'all':
        hurr_str = 'All Hurricanes'

    t_str = ''
    if t_score != 'all':
        t_str = f', T = {t_score}'

    intens_str = ''
    if intens_status != 'all':
        intens_str = f', {intens_status} Only'

    hurr_subset_str = f"{region_str}, {hurr_str}{t_str}{intens_str} (Total Samples: {total_time_bins})"
    plot_shear_dist_azimuth(dens_all_twicenormed_az, hurr_subset_str, bin_size_radial_rmw_mult, n_bins_radial, n_bins_angular)
    plot_shear_dist_rmw_xy(dens_all_twicenormed_rmw_xy, hurr_subset_str)
    #plot_shear_dist_rmw_xy(dens_all_twicenormed_rmw_xy, hurr_subset_str, bin_size_y=0.2)

# %%
#Code to make shear plots for a specific subset of the hurricane data (current 
#version iteratively generates all plots needed for streamlit app, but can be 
#customized for your needs)
region=DEFAULT_REGION
hurr_name_list = ['all', 'Barry', 'Bonnie', 'Dorian', 'Elsa', 'Danielle', 'Don', 'Earl', 'Grace', 
                  'Fiona', 'Hanna', 'Henri', 'Franklin', 'Humberto', 'Isaias', 'Ida', 'Ian', 'Jerry', 'Idalia', 'Larry', 
                  'Lorenzo', 'Laura', 'Julia', 'Lee', 'Marco', 'Nicholas', 'Margot', 'Lisa', 'Nigel', 'Nana', 'Martin', 
                  'Paulette', 'Nicole', 'Pablo', 'Sam', 'Sally', 'Teddy', 'Tammy', 'Gamma', 'Delta', 'Epsilon', 'Zeta', 'Eta', 'Iota']

#hurr_name_list = ['Bonnie', 'Elsa', 'Danielle', 'Don', 'Earl', 'Grace', 
#                  'Fiona', 'Henri', 'Franklin', 'Ida', 'Ian', 'Idalia', 'Larry', 
#                  'Julia', 'Lee', 'Nicholas', 'Margot', 'Lisa', 'Nigel', 'Martin', 
#                  'Nicole', 'Sam', 'Tammy']
t_score_list = ['all', 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7]
intens_status_list = ['all', 'RW', 'W', 'NC', 'I', 'RI']

for hurr_name in hurr_name_list:
    for t_score in t_score_list:
        for intens_status in intens_status_list:
            print(f'Hurricane Name: {hurr_name}, T Score: {t_score}, Intensification Status: {intens_status}')
            plot_filtered_data(region=region, hurr_name=hurr_name, t_score=t_score, intens_status=intens_status)
hurr_name = 'all'
t_score = 'all'
intens_status = 'RI'

#plot_filtered_data(hurr_name = hurr_name, t_score = t_score, intens_status=intens_status)
